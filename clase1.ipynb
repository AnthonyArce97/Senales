# %% [markdown]
# <a href="https://colab.research.google.com/github/AnthonyArce97/Senales/blob/master/clase1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# texto

# %%
import numpy as np
import matplotlib.pyplot as plt

# INGRESO
a= -5 # rango de tiempo
b= 5
dt= 0.1
sigma= 0 # s= 0+0j
omega= 0

# PROCEDIMIENTO
t = np.arange(a,b,dt)
s = complex(sigma,omega)
senal=np.exp(s*t)

# SALIDA - gráfica
plt.figure(1)
plt.plot(t,np.real(senal),label='Real')
plt.plot(t,np.imag(senal),label='Imginaria')
plt.xlabel('t')
plt.ylabel('x(t)')
plt.legend()
plt.margins(0.1)
plt.title('e^('+str(sigma)+'+'+str(omega)+'j)')
plt.show()

# %%
# INGRESO
a= -5 # rango de tiempo
b= 5
dt= 0.1
sigma= 1 # s= 0+0j
omega= 0

# PROCEDIMIENTO
t = np.arange(a,b,dt)
s = complex(sigma,omega)
senal=np.exp(s*t)

# SALIDA - gráfica
plt.figure(1)
plt.plot(t,np.real(senal),label='Real')
plt.plot(t,np.imag(senal),label='Imginaria')
plt.xlabel('t')
plt.ylabel('x(t)')
plt.legend()
plt.margins(0.1)
plt.title('e^('+str(sigma)+'+'+str(omega)+'j)')
plt.show()

# %%
# INGRESO
a= -5 # rango de tiempo
b= 5
dt= 0.1
sigma=-1 # s= 0+0j
omega= 0

# PROCEDIMIENTO
t = np.arange(a,b,dt)
s = complex(sigma,omega)
senal=np.exp(s*t)

# SALIDA - gráfica
plt.figure(1)
plt.plot(t,np.real(senal),label='Real')
plt.plot(t,np.imag(senal),label='Imginaria')
plt.xlabel('t')
plt.ylabel('x(t)')
plt.legend()
plt.margins(0.1)
plt.title('e^('+str(sigma)+'+'+str(omega)+'j)')
plt.show()

# %%
# INGRESO
a= -5 # rango de tiempo
b= 5
dt= 0.1
sigma= 0 # s= 0+0j
omega= 1

# PROCEDIMIENTO
t = np.arange(a,b,dt)
s = complex(sigma,omega)
senal=np.exp(s*t)

# SALIDA - gráfica
plt.figure(1)
plt.plot(t,np.real(senal),label='Real')
plt.plot(t,np.imag(senal),label='Imginaria')
plt.xlabel('t')
plt.ylabel('x(t)')
plt.legend()
plt.margins(0.1)
plt.title('e^('+str(sigma)+'+'+str(omega)+'j)')
plt.show()

# %%
# INGRESO
a= -5 # rango de tiempo
b= 5
dt= 0.1
sigma= -0.5 # s= 0+0j
omega= 1

# PROCEDIMIENTO
t = np.arange(a,b,dt)
s = complex(sigma,omega)
senal=np.exp(s*t)

# SALIDA - gráfica
plt.figure(1)
plt.plot(t,np.real(senal),label='Real')
plt.plot(t,np.imag(senal),label='Imginaria')
plt.xlabel('t')
plt.ylabel('x(t)')
plt.legend()
plt.margins(0.1)
plt.title('e^('+str(sigma)+'+'+str(omega)+'j)')
plt.show()

# %%
# INGRESO

sigma= 0 # s= 0+0j
omega= 1

# PROCEDIMIENTO

s = complex(sigma,omega)
senal=np.exp(s*t)

# SALIDA - gráfica
plt.figure(4)
plt.plot(np.real(senal),np.imag(senal),label='Complejo')

plt.xlabel('Real')
plt.ylabel('Imaginario')
plt.legend()
plt.margins(0.1)
plt.title('e^('+str(sigma)+'+'+str(omega)+'j)')
plt.show()

# %%
import scipy.integrate as integrate 

w=1
a=0.1
b=0
c=2*np.pi
dte=0.005


te= np.arange(b,c,dte)
xe=np.exp(-a*te)


cuadradoxe= xe**2
energiaxe = integrate.simps(cuadradoxe,te)

#Salida

print('La energia de xe es: ', energiaxe)

#Grafica

plt.plot(te,xe,label='xe')
plt.fill_between (te,0,cuadradoxe,color='Lightgreen')
plt.plot(te,cuadradoxe,'g--',label='xe^2')
plt.xlabel('t')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-05141278e84f> in <module>()
#       4 a=0.1
#       5 b=0
# ----> 6 c=2*np.pi
#       7 dte=0.005
#       8
#
# NameError: name 'np' is not defined

# %%
w=1
a=0
b= 2*np.pi
dte=0.005
Q=0
A=1


T= 2*np.pi/w
te= np.arange(a,b,dte)
xe=A*np.cos(w*te+Q)

cuadradoxe = xe**2
energiaxe = integrate.simps(cuadradoxe,te)
#Potencia en un periodo
potenciaxe = (1/T)*energiaxe
#Salida
print('la potencia de xe es', potenciaxe)

#grafica
plt.fill_between(te,0,xe,color='green')
plt.plot(te,xe,label='xe')
plt.fill_between(te,0,cuadradoxe,color='lightgreen')
plt.plot(te,cuadradoxe,'g--',label='xe^2')
plt.xlabel('t')
plt.legend()
plt.show()
4
# Out:
# la potencia de xe es 0.4994930443316458
